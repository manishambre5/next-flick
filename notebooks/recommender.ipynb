# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
import requests
import time
import warnings; warnings.simplefilter('ignore')
import os
os.makedirs('../backend/data', exist_ok=True)
import re
from collections import Counter
import pickle

# %%
# Reading Cleaned Dataset

md = pd.read_csv("../backend/data/good_cinema.csv")

# %% [markdown]
# ## Building the content-based recommendation system

# %%
# Implementing content based filtering based on Overviews, Cast, Director, Writer, and Genre

# %% [raw]
# # Checking most common abbreviations in 'overview'
#
# import re
# from collections import Counter
#
# # Extract and count all potential abbreviations
# abbrev_counts = Counter()
# for text in md['overview'].dropna():
#     matches = re.findall(r'\b[A-Z]{2,}\b', text)  # Matches 2+ uppercase letters
#     abbrev_counts.update(matches)
#
# # Print total unique abbreviations
# print(f"Total unique abbreviations: {len(abbrev_counts)}")
#
# # Print abbreviations sorted by frequency (most common first)
# print("\nTop abbreviations by frequency:")
# for abbrev, count in abbrev_counts.most_common():  # sorts by count descending
#     print(f"{abbrev}: {count}")

# %% [raw]
# # Checking the most common named entities
#
# def find_named_entities(text):
#     if pd.isna(text):
#         return []
#     return re.findall(r'\b(?:[A-Z][a-z\'’-]*\s)+[A-Z][a-z\'’-]*\b', str(text))
#
# # Get most common entities
# named_entities = md['overview'].apply(find_named_entities).explode().value_counts().head(50)
#
# named_entities

# %%
# For manual standardization of most common named entities

MOVIE_ENTITY_ABBREVIATIONS = {
    # Wars and Historical Events
    r'\bworld war i\b': 'WWI',
    r'\bworld war ii\b': 'WWII',
    r'\bworld war 1\b': 'WWI',
    r'\bworld war 2\b': 'WWII',
    r'\bthe great war\b': 'WWI',
    r'\bsecond world war\b': 'WWII',
    
    # Popular Movie Franchises
    r'\bstar wars(?:\s*episode\s*[ivxlcdm]+)?\b': 'SW',
    r'\blord of the rings\b': 'LOTR',
    r'\bthe lord of the rings\b': 'LOTR',
    r'\bmarvel cinematic universe\b': 'MCU',
    r'\bdc extended universe\b': 'DCEU',
    
    # Countries/Regions
    r'\bunited states\b': 'US',
    r'\bunited states of america\b': 'US',
    r'\bamerica\b': 'US',
    r'\busa\b': 'US',
    r'\bunited kingdom\b': 'UK',
    r'\bgreat britain\b': 'UK',
    r'\bsoviet union\b': 'USSR',
    
    # Time Periods
    r'\b17\d{2}s\b': r'\g<0>',  # Preserve "1980s" etc
    r'\b18\d{2}s\b': r'\g<0>',
    r'\b19\d{2}s\b': r'\g<0>',
    r'\b20\d{2}s\b': r'\g<0>',
}

# %%
# Standardizing the named entities from the MOVIE_ENTITY_ABBREVIATIONS dictionary

def standardize_entities(text, abbreviation_map=None):
    if pd.isna(text):
        return ""
    
    if abbreviation_map is None:
        abbreviation_map = MOVIE_ENTITY_ABBREVIATIONS
    
    standardized = text
    for pattern, abbrev in abbreviation_map.items():
        standardized = re.sub(
            pattern, 
            abbrev, 
            standardized, 
            flags=re.IGNORECASE
        )
    return standardized

# %%
# Processing 'overview'

md['processed_overview'] = (
    md['overview']
    .apply(standardize_entities)  # manual standardization
    .str.lower()                 # lowercasing
    .apply(lambda x: re.sub(r'[^\w\s]', '', x))  # Removing punctuation
    .apply(lambda x: ' '.join([w for w in x.split() if len(w) > 2])))  # Removing short words

# %% [raw]
# # Searching for named entities in 'overview' for validation...
#
# with pd.option_context('display.max_columns', None, 'display.max_colwidth', None): # to display complete data
#     print(md[md['processed_overview'].str.contains(' II ')]['processed_overview'])

# %%
all_genres = pd.Series([genre.strip() for sublist in md['genres'].str.split(',') for genre in sublist]).unique()

# %%
# Removing Space between words so that our engine doesn't confuse between Ryan Gosling and Ryan Reynolds

md['genres_clean'] = md['genres'].str.replace(' ', '')
md['directors_clean'] = md['directed_by'].str.replace(' ', '')
md['writers_clean'] = md['written_by'].str.replace(' ', '')
md['cast_clean'] = md['cast'].str.replace(' ', '')

# Replacing commas with a space for TF-IDF

md['genres_clean'] = md['genres_clean'].str.replace(',', ' ')
md['directors_clean'] = md['directors_clean'].str.replace(',', ' ')
md['writers_clean'] = md['writers_clean'].str.replace(',', ' ')
md['cast_clean'] = md['cast_clean'].str.replace(',', ' ')

# Replacing NaNs with empty string

md.fillna({'processed_overview': '', 'genres_clean': '', 'directors_clean': '', 'writers_clean': '', 'cast_clean': ''}, inplace=True)

md[['cast_clean','directors_clean']].head(5)
#md[md['directed_by'].str.contains(',',na=False)].head(10)['directed_by']
# Out:
#                                           cast_clean  \
# 0  EetuHilkamo TuroPajala JormaMarkkula HannuKivi...
# 1  HaijeAlanoja AkiKaurismäki Jukka-PekkaPalo Esk...
# 2  AntonioBanderas SammiDavis KimberlyBlair PaulS...
# 3  StephenDorff DeirdreKelly EmilioEstevez Robert...
# 4  HalWamsley RobertA.Denham PamRose TimCondren I...
#
#                                      directors_clean
# 0                                      AkiKaurismäki
# 1                                      AkiKaurismäki
# 2  AllisonAnders QuentinTarantino RobertRodriguez...
# 3                                     StephenHopkins
# 4                                        GeorgeLucas

# %%
# Creating a custom transformer for each feature

class ColumnExtractor(BaseEstimator, TransformerMixin):
    def __init__(self, column):
        self.column = column
        
    def fit(self, X, y=None):
        return self
        
    def transform(self, X):
        return X[self.column]

# %%
# Define vectorizers

overview_tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), stop_words='english', min_df=0.0,)  # overview
people_tfidf = TfidfVectorizer(analyzer='word', min_df=0.0)  # directors, writers, cast
genres_tfidf = TfidfVectorizer(analyzer='word', min_df=0.0) # genres

# %%
# Creating the FeatureUnion pipeline

feature_union = FeatureUnion([
    ('overview', Pipeline([
        ('extractor', ColumnExtractor('processed_overview')),
        ('tfidf', overview_tfidf)
    ])),
    ('genres', Pipeline([
        ('extractor', ColumnExtractor('genres_clean')),
        ('tfidf', genres_tfidf)
    ])),
    ('directors', Pipeline([
        ('extractor', ColumnExtractor('directors_clean')),
        ('tfidf', people_tfidf)
    ])),
    ('writers', Pipeline([
        ('extractor', ColumnExtractor('writers_clean')),
        ('tfidf', people_tfidf)
    ])),
    ('cast', Pipeline([
        ('extractor', ColumnExtractor('cast_clean')),
        ('tfidf', people_tfidf)
    ]))
])

# %%
# Generating combined TF-IDF matrix

tfidf_matrix = feature_union.fit_transform(md)

# %%
tfidf_matrix.shape
# Out:
# (18790, 717128)

# %%
# Computing cosine similarity

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim.shape
# Out:
# (18790, 18790)

# %%
md = md.reset_index()
titles = md['title']
indices = pd.Series(md.index, index=md['title'])

# %%
def get_recommendations(title, cosine_sim=cosine_sim, movies_df=md, top_n=10):
    idx = indices[title]  # Find movie index
    sim_scores = list(enumerate(cosine_sim[idx]))  # Get similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)  # Sort
    sim_scores = sim_scores[1:top_n+1]  # Exclude self & get top matches
    movie_indices = [i[0] for i in sim_scores]
    return movies_df.iloc[movie_indices]  # Return recommendations

# %%
get_recommendations('I, Daniel Blake').head(10)
# Out:
#        index     imdb_id  tmdb_id                            title  \
# 15663  15663   tt8359816   522369              Sorry We Missed You
# 17931  17931  tt19883634   970348                      The Old Oak
# 2072    2072   tt0807054     7992             It's a Free World...
# 2109    2109   tt0151691     8129                   My Name Is Joe
# 5539    5539   tt1242545    18898                 Looking for Eric
# 8075    8075   tt0212826    37691                  Bread and Roses
# 11356  11356   tt1924394   103747                The Angels' Share
# 839      839   tt0380366     1404                  Ae Fond Kiss...
# 823      823   tt0313670     1376                    Sweet Sixteen
# 770      770   tt0460989     1116  The Wind That Shakes the Barley
#
#                         original_title  \
# 15663              Sorry We Missed You
# 17931                      The Old Oak
# 2072              It's a Free World...
# 2109                    My Name Is Joe
# 5539                  Looking for Eric
# 8075                   Bread and Roses
# 11356                The Angels' Share
# 839                    Ae Fond Kiss...
# 823                      Sweet Sixteen
# 770    The Wind That Shakes the Barley
#
#                                                 overview  imdb_rating  \
# 15663  Ricky and his family have been fighting an uph...          7.6
# 17931  A pub landlord in a previously thriving mining...          7.1
# 2072   Angie is a working class woman. After being fi...          7.0
# 2109   Two thirtysomethings, unemployed former alcoho...          7.4
# 5539   A man trying to put his life back on track get...          7.1
# 8075   Maya is a quick-witted young woman who comes o...          7.0
# 11356  Narrowly avoiding jail, new dad Robbie vows to...          7.0
# 839    A young man upsets his Punjabi family when he ...          7.1
# 823    Determined to have a normal family life once h...          7.4
# 770    In 1920s Ireland young doctor Damien O'Donovan...          7.5
#
#        imdb_votes          genres  \
# 15663     27052.0           Drama
# 17931     12647.0           Drama
# 2072       6426.0           Drama
# 2109       9135.0           Drama
# 5539      18330.0   Drama, Comedy
# 8075       6249.0   Comedy, Drama
# 11356     27609.0   Drama, Comedy
# 839        7480.0  Drama, Romance
# 823       16120.0    Crime, Drama
# 770       56652.0      Drama, War
#
#                                                     cast  ...  \
# 15663  Andy Kidd, Lee Hall, Randolph Paul, Christine ...  ...
# 17931  Chrissie Robinson, Ali Mohamed, Sabah Hassoun,...  ...
# 2072   Kierston Wareing, Frank Gilhooley, Davoud Rast...  ...
# 2109   Paul Gillan, Louise Goodall, Ann Marie Laffert...  ...
# 5539   Justin Moorhouse, Stefan Gumbs, Mick Ferry, Ry...  ...
# 8075   Maria Orellana, Sherman Augustus, Tom Gilroy, ...  ...
# 11356  Gary Maitland, Scott Dymond, Caz Dunlop, Finla...  ...
# 839    Ahmad Riaz, Karen Fraser, John Yule, Shabana A...  ...
# 823    Junior Walker, William Ruane, Rikki Traynor, T...  ...
# 770    Tim O'Mahon, Colin McClery, Aine O'Connor, Mar...  ...
#
#                    cinematography       music_by release_date  \
# 15663                 Robbie Ryan  George Fenton   2019-10-04
# 17931                 Robbie Ryan  George Fenton   2023-09-29
# 2072             Nigel Willoughby  George Fenton   2007-09-28
# 2109                Barry Ackroyd  George Fenton   1998-05-15
# 5539                Barry Ackroyd  George Fenton   2009-05-27
# 8075                Barry Ackroyd  George Fenton   2000-09-14
# 11356  Robbie Ryan, Barry Ackroyd  George Fenton   2012-06-01
# 839                 Barry Ackroyd  George Fenton   2004-02-13
# 823                 Barry Ackroyd  George Fenton   2002-09-07
# 770                 Barry Ackroyd  George Fenton   2006-06-23
#
#       original_language                       poster_path  \
# 15663                en  /jNvlqNDnXH8aqBeiBxNNP0wWWO3.jpg
# 17931                en  /xN293BKB0MDqpILmLCtGGYxQXKW.jpg
# 2072                 en  /mf21jW15cjoe95yIW1DvlYUN4YO.jpg
# 2109                 en  /e9awu6tsCyWPAUA2eEoelFSTbcb.jpg
# 5539                 en  /fTHUY0E1FYMFKiQ8UDKx793LtW0.jpg
# 8075                 en  /aNk0yx0xRcs66OdByiy2pJaFhI6.jpg
# 11356                en  /bt9kJ8gwTMaDcmL0INlJYIZ887t.jpg
# 839                  en  /tShULKbs8svdBcekljqGPO42PNj.jpg
# 823                  en  /p5h50WEZQ4pRFffnSULqL4cEuLp.jpg
# 770                  en  /9XquDdOGrlC0EAbPoOXALqS2dDh.jpg
#
#                                       processed_overview   genres_clean  \
# 15663  ricky and his family have been fighting uphill...          Drama
# 17931  pub landlord previously thriving mining commun...          Drama
# 2072   angie working class woman after being fired sh...          Drama
# 2109   two thirtysomethings unemployed former alcohol...          Drama
# 5539   man trying put his life back track gets some a...   Drama Comedy
# 8075   maya quickwitted young woman who comes over th...   Comedy Drama
# 11356  narrowly avoiding jail new dad robbie vows tur...   Drama Comedy
# 839    young man upsets his punjabi family when falls...  Drama Romance
# 823    determined have normal family life once his mo...    Crime Drama
# 770    1920s ireland young doctor damien odonovan pre...      Drama War
#
#       directors_clean writers_clean  \
# 15663        KenLoach   PaulLaverty
# 17931        KenLoach   PaulLaverty
# 2072         KenLoach   PaulLaverty
# 2109         KenLoach   PaulLaverty
# 5539         KenLoach   PaulLaverty
# 8075         KenLoach   PaulLaverty
# 11356        KenLoach   PaulLaverty
# 839          KenLoach   PaulLaverty
# 823          KenLoach   PaulLaverty
# 770          KenLoach   PaulLaverty
#
#                                               cast_clean
# 15663  AndyKidd LeeHall RandolphPaul ChristineBeck Ru...
# 17931  ChrissieRobinson AliMohamed SabahHassoun KikaM...
# 2072   KierstonWareing FrankGilhooley DavoudRastgou J...
# 2109   PaulGillan LouiseGoodall AnnMarieLafferty Simo...
# 5539   JustinMoorhouse StefanGumbs MickFerry RyanPope...
# 8075   MariaOrellana ShermanAugustus TomGilroy Cooper...
# 11356  GaryMaitland ScottDymond CazDunlop FinlayHarri...
# 839    AhmadRiaz KarenFraser JohnYule ShabanaAkhtarBa...
# 823    JuniorWalker WilliamRuane RikkiTraynor TommyMc...
# 770    TimO'Mahon ColinMcClery AineO'Connor MarkBryce...
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Exporting components

# %%
# Saving the TF-IDF vectorizer
with open('../backend/data/tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf_matrix, f)

# Saving the cosine similarity matrix for fast lookups
with open('../backend/data/cosine_sim.pkl', 'wb') as f:
    pickle.dump(cosine_sim, f)
